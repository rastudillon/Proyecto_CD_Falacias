# %%
import os
import re

directory_path = r'C:\Users\Usuario\Mi unidad\Proyecto Ciencia de Datos II\sesiones'

start_marker = r"I\. ASISTENCIA"
end_marker = r"-Concurri"

for filename in os.listdir(directory_path):
    if filename.endswith(".txt"):
        file_path = os.path.join(directory_path, filename)

        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()

        attendance_section = re.search(f"{start_marker}.*?(-Asistieron.*?){end_marker}", content, re.DOTALL)
        if attendance_section:
            attendance_list = attendance_section.group(1)
        else:
            attendance_list = "No se encontró la lista de asistencia entre los marcadores especificados."

        output_file_path = os.path.join(directory_path, f'asistencia_{filename}')

        with open(output_file_path, 'w', encoding='utf-8') as output_file:
            output_file.write(attendance_list)
            print(f"El texto ha sido guardado exitosamente en '{output_file_path}'.")
    else:
        continue
# Out:
# El texto ha sido guardado exitosamente en 'C:\Users\Usuario\Mi unidad\Proyecto Ciencia de Datos II\sesiones\asistencia_contenido_sesion_3655.txt'.
# El texto ha sido guardado exitosamente en 'C:\Users\Usuario\Mi unidad\Proyecto Ciencia de Datos II\sesiones\asistencia_contenido_sesion_3656.txt'.
# El texto ha sido guardado exitosamente en 'C:\Users\Usuario\Mi unidad\Proyecto Ciencia de Datos II\sesiones\asistencia_contenido_sesion_3657.txt'.
# El texto ha sido guardado exitosamente en 'C:\Users\Usuario\Mi unidad\Proyecto Ciencia de Datos II\sesiones\asistencia_contenido_sesion_3658.txt'.
# El texto ha sido guardado exitosamente en 'C:\Users\Usuario\Mi unidad\Proyecto Ciencia de Datos II\sesiones\asistencia_contenido_sesion_3659.txt'.
# El texto ha sido guardado exitosamente en 'C:\Users\Usuario\Mi unidad\Proyecto Ciencia de Datos II\sesiones\asistencia_contenido_sesion_3660.txt'.
# ...

# %%
import os
import re

# Directorio donde se encuentran los archivos .txt
directory_path = r'C:\Users\Usuario\Mi unidad\Proyecto Ciencia de Datos II\sesiones'

# Definir los marcadores de inicio y fin
start_marker = r"I\. ASISTENCIA"
end_marker = r"-Concurri"  # Base común para "Concurrió" y "Concurrieron"

# Iterar sobre cada archivo en el directorio especificado
for filename in os.listdir(directory_path):
    if filename.endswith(".txt"):  # Verificar que el archivo sea un archivo de texto
        file_path = os.path.join(directory_path, filename)

        # Leer el contenido del archivo
        with open(file_path, 'r', encoding='utf-8') as file:
            lines = file.readlines()
        
        # Extraer las primeras cinco líneas para procesarlas de acuerdo a necesidades específicas
        first_five_lines = "".join(lines[:5])

        # Reunir el contenido completo del archivo para la búsqueda posterior
        content = "".join(lines)

        # Buscar la sección de asistencia comenzando en "-Asistieron" después de "I. ASISTENCIA" hasta una forma que comienza con "-Concurri"
        attendance_section = re.search(f"{start_marker}.*?(-Asistieron.*?){end_marker}", content, re.DOTALL)
        if attendance_section:
            attendance_list = attendance_section.group(1)  # El grupo 1 contiene el texto desde "-Asistieron" hasta antes de "-Concurri"
        else:
            attendance_list = "No se encontró la lista de asistencia entre los marcadores especificados."

        # Preparar el contenido a guardar, incluyendo las primeras cinco líneas y la lista de asistencia
        output_content = first_five_lines + attendance_list

        # Definir la ruta del archivo de salida
        output_file_path = os.path.join(directory_path, f'asistencia_{filename}')

        # Escribir el resultado en el archivo de salida
        with open(output_file_path, 'w', encoding='utf-8') as output_file:
            output_file.write(output_content)
            print(f"El texto ha sido guardado exitosamente en '{output_file_path}'.")
    else:
        continue  # Si el archivo no es un .txt, continúa con el siguiente archivo
# Out:
# El texto ha sido guardado exitosamente en 'C:\Users\Usuario\Mi unidad\Proyecto Ciencia de Datos II\sesiones\asistencia_contenido_sesion_3655.txt'.
# El texto ha sido guardado exitosamente en 'C:\Users\Usuario\Mi unidad\Proyecto Ciencia de Datos II\sesiones\asistencia_contenido_sesion_3656.txt'.
# El texto ha sido guardado exitosamente en 'C:\Users\Usuario\Mi unidad\Proyecto Ciencia de Datos II\sesiones\asistencia_contenido_sesion_3657.txt'.
# El texto ha sido guardado exitosamente en 'C:\Users\Usuario\Mi unidad\Proyecto Ciencia de Datos II\sesiones\asistencia_contenido_sesion_3658.txt'.
# El texto ha sido guardado exitosamente en 'C:\Users\Usuario\Mi unidad\Proyecto Ciencia de Datos II\sesiones\asistencia_contenido_sesion_3659.txt'.
# El texto ha sido guardado exitosamente en 'C:\Users\Usuario\Mi unidad\Proyecto Ciencia de Datos II\sesiones\asistencia_contenido_sesion_3660.txt'.
# ...

# %%
import os
import re

# Directorio donde se encuentran los archivos .txt
directory_path = r'C:\Users\Usuario\Mi unidad\Proyecto Ciencia de Datos II\sesiones'

# Definir los marcadores de inicio y fin, incorporando un apóstrofe opcional después de "Concurri"
start_marker = r"I\. ASISTENCIA"
end_marker = r"-Concurri'?,"  # Añade un apóstrofe opcional antes de la coma

# Iterar sobre cada archivo en el directorio especificado
for filename in os.listdir(directory_path):
    if filename.endswith(".txt"):  # Verificar que el archivo sea un archivo de texto
        file_path = os.path.join(directory_path, filename)

        # Leer el contenido del archivo
        with open(file_path, 'r', encoding='utf-8') as file:
            lines = file.readlines()
        
        # Extraer las primeras cinco líneas para incluirlas en el archivo de salida
        first_five_lines = "".join(lines[:5])

        # Reunir el contenido completo del archivo para la búsqueda posterior
        content = "".join(lines)

        # Buscar la sección de asistencia comenzando en "-Asistieron" después de "I. ASISTENCIA" hasta una forma que comienza con "-Concurri"
        attendance_section = re.search(f"{start_marker}.*?(-Asistieron.*?){end_marker}", content, re.DOTALL)
        if attendance_section:
            attendance_list = attendance_section.group(1)  # El grupo 1 contiene el texto desde "-Asistieron" hasta antes de "-Concurri"
        else:
            attendance_list = "No se encontró la lista de asistencia entre los marcadores especificados."

        # Preparar el contenido a guardar, incluyendo las primeras cinco líneas y la lista de asistencia
        output_content = first_five_lines + attendance_list

        # Definir la ruta del archivo de salida
        output_file_path = os.path.join(directory_path, f'processed_{filename}')

        # Escribir el resultado en el archivo de salida
        with open(output_file_path, 'w', encoding='utf-8') as output_file:
            output_file.write(output_content)
            print(f"El texto ha sido guardado exitosamente en '{output_file_path}'.")
    else:
        continue  # Si el archivo no es un .txt, continúa con el siguiente archivo
# Out:
# El texto ha sido guardado exitosamente en 'C:\Users\Usuario\Mi unidad\Proyecto Ciencia de Datos II\sesiones\processed_contenido_sesion_3655.txt'.
# El texto ha sido guardado exitosamente en 'C:\Users\Usuario\Mi unidad\Proyecto Ciencia de Datos II\sesiones\processed_contenido_sesion_3656.txt'.
# El texto ha sido guardado exitosamente en 'C:\Users\Usuario\Mi unidad\Proyecto Ciencia de Datos II\sesiones\processed_contenido_sesion_3657.txt'.
# El texto ha sido guardado exitosamente en 'C:\Users\Usuario\Mi unidad\Proyecto Ciencia de Datos II\sesiones\processed_contenido_sesion_3658.txt'.
# El texto ha sido guardado exitosamente en 'C:\Users\Usuario\Mi unidad\Proyecto Ciencia de Datos II\sesiones\processed_contenido_sesion_3659.txt'.
# El texto ha sido guardado exitosamente en 'C:\Users\Usuario\Mi unidad\Proyecto Ciencia de Datos II\sesiones\processed_contenido_sesion_3660.txt'.
# ...

# %%
import os
import re

# Directorio donde se encuentran los archivos .txt
directory_path = r'C:\Users\Gozu\Mi unidad\Proyecto Ciencia de Datos II\PDF Sesiones camara de Diputados\Legislatura 332_'

# Definir los marcadores de inicio y fin, incorporando las diferentes terminaciones
start_marker = r"I. ASISTENCIA"
end_marker = r"II. APERTURA DE LA SESIÓN"

# Iterar sobre cada archivo en el directorio especificado
for filename in os.listdir(directory_path):
    if filename.endswith(".txt"):  # Verificar que el archivo sea un archivo de texto
        file_path = os.path.join(directory_path, filename)

        # Leer el contenido del archivo
        with open(file_path, 'r', encoding='utf-8') as file:
            lines = file.readlines()
        
        # Extraer las primeras cinco líneas para incluirlas en el archivo de salida
        first_five_lines = "".join(lines[10:18])

        # Reunir el contenido completo del archivo para la búsqueda posterior
        content = "".join(lines)#[268:])

        # Buscar la sección de asistencia comenzando en "-Asistieron" después de "I. ASISTENCIA" hasta la variación del marcador final
        attendance_section = re.search(f"{start_marker}.*?(-Asis.*?){end_marker}", content, re.DOTALL)
        if attendance_section:
            attendance_list = attendance_section.group(1)  # El grupo 1 contiene el texto desde "-Asistieron" hasta antes del marcador final
        else:
            attendance_list = "No se encontró la lista de asistencia entre los marcadores especificados."

        # Preparar el contenido a guardar, incluyendo las primeras cinco líneas y la lista de asistencia
        output_content = first_five_lines + attendance_list

        # Definir la ruta del archivo de salida
        output_file_path = os.path.join(directory_path, f'asistencia_{filename}')

        # Escribir el resultado en el archivo de salida
        with open(output_file_path, 'w', encoding='utf-8') as output_file:
            output_file.write(output_content)
            print(f"El texto ha sido guardado exitosamente en '{output_file_path}'.")
    else:
        continue  # Si el archivo no es un .txt, continúa con el siguiente archivo
# Out:
# El texto ha sido guardado exitosamente en 'C:\Users\Gozu\Mi unidad\Proyecto Ciencia de Datos II\PDF Sesiones camara de Diputados\Legislatura 332_\asistencia_leg_332_s1.txt'.
# El texto ha sido guardado exitosamente en 'C:\Users\Gozu\Mi unidad\Proyecto Ciencia de Datos II\PDF Sesiones camara de Diputados\Legislatura 332_\asistencia_verdoc (1).txt'.
# El texto ha sido guardado exitosamente en 'C:\Users\Gozu\Mi unidad\Proyecto Ciencia de Datos II\PDF Sesiones camara de Diputados\Legislatura 332_\asistencia_verdoc (10).txt'.
# El texto ha sido guardado exitosamente en 'C:\Users\Gozu\Mi unidad\Proyecto Ciencia de Datos II\PDF Sesiones camara de Diputados\Legislatura 332_\asistencia_verdoc (11).txt'.
# El texto ha sido guardado exitosamente en 'C:\Users\Gozu\Mi unidad\Proyecto Ciencia de Datos II\PDF Sesiones camara de Diputados\Legislatura 332_\asistencia_verdoc (12).txt'.
# ...

# %%
import os
import re

# Directorio donde se encuentran los archivos .txt
directory_path = r'C:\Users\Gozu\Mi unidad\Proyecto Ciencia de Datos II\PDF Sesiones camara de Diputados\Legislatura 372'

# Definir los marcadores de inicio y fin, incorporando las diferentes terminaciones
start_marker = r"I. ASISTENCIA"
end_marker = r"APERTURA DE LA SESIÓN"

# Iterar sobre cada archivo en el directorio especificado
for filename in os.listdir(directory_path):
    if filename.endswith(".txt"):  # Verificar que el archivo sea un archivo de texto
        file_path = os.path.join(directory_path, filename)

        # Leer el contenido del archivo
        with open(file_path, 'r', encoding='utf-8') as file:
            lines = file.readlines()
        
        # Extraer las primeras cinco líneas para incluirlas en el archivo de salida
        first_five_lines = "".join(lines[10:18])

        # Reunir el contenido completo del archivo para la búsqueda posterior
        content = "".join(lines)#[268:])

        # Buscar la sección de asistencia comenzando en "-Asistieron" después de "I. ASISTENCIA" hasta la variación del marcador final
        attendance_section = re.search(f"{start_marker}.*?(-Asis.*?){end_marker}", content, re.DOTALL)
        if attendance_section:
            attendance_list = attendance_section.group(1)  # El grupo 1 contiene el texto desde "-Asistieron" hasta antes del marcador final
        else:
            attendance_list = "No se encontró la lista de asistencia entre los marcadores especificados."

        # Preparar el contenido a guardar, incluyendo las primeras cinco líneas y la lista de asistencia
        output_content = first_five_lines + attendance_list

        # Definir la ruta del archivo de salida
        output_file_path = os.path.join(directory_path, f'asistencia_{filename}')

        # Escribir el resultado en el archivo de salida
        with open(output_file_path, 'w', encoding='utf-8') as output_file:
            output_file.write(output_content)
            print(f"El texto ha sido guardado exitosamente en '{output_file_path}'.")
    else:
        continue  # Si el archivo no es un .txt, continúa con el siguiente archivo
# Out:
# El texto ha sido guardado exitosamente en 'C:\Users\Gozu\Mi unidad\Proyecto Ciencia de Datos II\PDF Sesiones camara de Diputados\Legislatura 372\asistencia_leg_372_s1.txt'.
# El texto ha sido guardado exitosamente en 'C:\Users\Gozu\Mi unidad\Proyecto Ciencia de Datos II\PDF Sesiones camara de Diputados\Legislatura 372\asistencia_verdoc (1).txt'.
# El texto ha sido guardado exitosamente en 'C:\Users\Gozu\Mi unidad\Proyecto Ciencia de Datos II\PDF Sesiones camara de Diputados\Legislatura 372\asistencia_verdoc (10).txt'.
# El texto ha sido guardado exitosamente en 'C:\Users\Gozu\Mi unidad\Proyecto Ciencia de Datos II\PDF Sesiones camara de Diputados\Legislatura 372\asistencia_verdoc (11).txt'.
# El texto ha sido guardado exitosamente en 'C:\Users\Gozu\Mi unidad\Proyecto Ciencia de Datos II\PDF Sesiones camara de Diputados\Legislatura 372\asistencia_verdoc (12).txt'.
# ...
